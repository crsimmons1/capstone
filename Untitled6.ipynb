# %%
import pandas as pd
import numpy as np
from datascience import *

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %%
data = pd.read_csv("missing_pieces_data_11-20-2017.csv")
california = data[data["STATE"] == "CA"]
#california
type(california)
# Out:
# //anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (13,16,17,18,19,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# pandas.core.frame.DataFrame

# %%
type(california["OFFENSE"])
# Out:
# pandas.core.series.Series

# %%
remove_na_cal = california[california['OFFENSE'].isna() == False]

# %%
cal_nona = remove_na_cal[remove_na_cal["OFFENSE"].str.contains("SCHOOL")]
cal_nona
# Out:
#         RECORD ID  MATCH ID STATE    LOCATION             AGENCY ORIGINAL  \
# 44611       44612       NaN    CA     KERN CO                  KERN CO SO
# 48805       48806       NaN    CA  SACRAMENTO               SACRAMENTO PD
# 52249       52250       NaN    CA  SACRAMENTO               SACRAMENTO PD
# 374790     374791       NaN    CA  LONG BEACH               LONG BEACH PD
# 375249     375250       NaN    CA  LONG BEACH               LONG BEACH PD
# 376532     376533       NaN    CA  LONG BEACH               LONG BEACH PD
# 376889     376890       NaN    CA  LONG BEACH               LONG BEACH PD
# 380083     380084       NaN    CA  LONG BEACH               LONG BEACH PD
# 380387     380388       NaN    CA  LONG BEACH               LONG BEACH PD
# 564181     564182       NaN    CA    LA MESA                   LA MESA PD
# 564182     564183       NaN    CA    LA MESA                   LA MESA PD
# 564183     564184       NaN    CA    LA MESA                   LA MESA PD
# ...

# %%
np.isnan(data.iloc[794350]["OFFENSE"])
# Out:
# True

# %%
cal_year = cal_nona.YEAR
cal_year
#cal_year_dist = cal_nona.groupby('YEAR')
#cal_year_dist
# Out:
# 44611     2012.0
# 48805     2011.0
# 52249     2015.0
# 374790    2010.0
# 375249    2010.0
# 376532    2011.0
# 376889    2012.0
# 380083    2015.0
# 380387    2016.0
# 564181    2015.0
# 564182    2015.0
# 564183    2015.0
# 564184    2015.0
# 564185    2015.0
# 570718    2011.0
# 570719    2011.0
# 570720    2011.0
# 571205    2011.0
# 572532    2012.0
# 575025    2013.0
# 578013    2015.0
# 579932    2016.0
# 580265    2016.0
# 580266    2016.0
# 580625    2010.0
# 580819    2011.0
# 580874    2011.0
# 580880    2011.0
# 580882    2011.0
# 581165    2013.0
# 589107    2007.0
# 591447    2013.0
# 591448    2013.0
# 793761    2012.0
# 793775    2013.0
# 793971    2014.0
# 794065    2015.0
# 794066    2015.0
# Name: YEAR, dtype: float64

# %%
year_count = cal_nona.groupby(['YEAR']).size()

# %%
year_df = year_count.reset_index().rename(columns={"YEAR":"YEAR", 0:"COUNT"})
year_df
# Out:
#      YEAR  COUNT
# 0  2007.0      1
# 1  2010.0      3
# 2  2011.0     10
# 3  2012.0      4
# 4  2013.0      5
# 5  2014.0      1
# 6  2015.0     10
# 7  2016.0      4

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

objects = year_df["YEAR"]
range_val = np.arange(year_df["COUNT"].max() + 1)
performance = year_df["COUNT"]
plt.bar(objects, performance, color='blue')
plt.xlabel("Year")
plt.ylabel("Number of Incidents")
plt.title("Incidents by Year")
plt.xticks(objects)
plt.show()
